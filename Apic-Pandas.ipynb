# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '1.2.4'

# %%
list = ['one', 'two', 45,345, 3.33]

# %%
series1 = pd.Series(list)

# %%
print(series1)
# Out:
# 0     one
# 1     two
# 2      45
# 3     345
# 4    3.33
# dtype: object

# %%
type(series1)
# Out:
# pandas.core.series.Series

# %%
series2 = pd.Series([5,6,33,55], index = ['a','f', 'v','m'])
print(series2)
# Out:
# a     5
# f     6
# v    33
# m    55
# dtype: int64

# %%
series3 = pd.Series([5,6,33,55], index = ['a','f', 'v','m'], dtype = float)
print(series3)
# Out:
# a    True
# f    True
# v    True
# m    True
# dtype: bool

# %%
series4 = pd.Series([5,6,33,55], index = ['a','f', 'v','m'], dtype = bool)
print(series4)
# Out:
# a    True
# f    True
# v    True
# m    True
# dtype: bool

# %%
series5 = pd.Series([5,6,33,55], index = ['a','f', 'v','m'], dtype = int, name = 'datavalues')
print(series5)
# Out:
# a     5
# f     6
# v    33
# m    55
# Name: datavalues, dtype: int64

# %%
sclar_values = pd.Series(0.5)
print(sclar_values)
# Out:
# 0    0.5
# dtype: float64

# %%
sclar_values = pd.Series(0.5, index=[1, 'a'])
print(sclar_values)
# Out:
# 1    0.5
# a    0.5
# dtype: float64

# %%
dict_1 = pd.Series({
    1 : 'one',
    2 : 'two',
    'king' : 'kong',
    'pandas' : 'python'
}) 

d_1 = pd.Series(dict_1)
print(d_1)
# Out:
# 1            one
# 2            two
# king        kong
# pandas    python
# dtype: object

# %%
d_1[2]
# Out:
# 'two'

# %%
d_1['king']
# Out:
# 'kong'

# %%
d_1[1 : 'king']            # slicing!!!
# Out:
# 1        one
# 2        two
# king    kong
# dtype: object

# %%
max(d_1)
# Out:
# 'two'

# %%
min(d_1)
# Out:
# 'kong'

# %%
d_1[d_1 > 1]                   # conditionals operators

# %%
dict_2 =({
    1 : 4,
    2 : 3,
    3 : 1
})
d_2 =pd.Series(dict_2)
print(d_2)
# Out:
# 1    4
# 2    3
# 3    1
# dtype: int64

# %%
dict_3 =({
    1 : 1,
    2 : 2,
    3 : 5
})
d_3 =pd.Series(dict_3)
print(d_3)
# Out:
# 1    1
# 2    2
# 3    5
# dtype: int64

# %%
d_2 + d_3
# Out:
# 1    5
# 2    5
# 3    6
# dtype: int64

# %%
##   How to create pandas DataFrame

# %%
df_1 = pd.DataFrame() 
print(df_1)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# df_1 = pd.DataFrame()
# print(df_1)

# %%
lst = ['a','B','C',3]
df_2 = pd.DataFrame(lst)
print(df_2)
# Out:
#    0
# 0  a
# 1  B
# 2  C
# 3  3

# %%
df_2
# Out:
#    0
# 0  a
# 1  B
# 2  C
# 3  3

# %%
lst_of_lst = [[1,2,3], [4,5,6], [7,8,9]]
df_3 = pd.DataFrame(lst_of_lst)
print(df_3)
# Out:
#    0  1  2
# 0  1  2  3
# 1  4  5  6
# 2  7  8  9

# %%
df_3
# Out:
#    0  1  2
# 0  1  2  3
# 1  4  5  6
# 2  7  8  9

# %%
dic_1 = {
    'Name' : ['king','kong'],
    'UNI' : ['Fast','Science'],
    'len' : [123, 46],
    'num' : [9, 56]
}
di_1 = pd.DataFrame(dic_1)
print(di_1)
# Out:
#    Name      UNI  len  num
# 0  king     Fast  123    9
# 1  kong  Science   46   56

# %%
di_1
# Out:
#    Name      UNI  len  num
# 0  king     Fast  123    9
# 1  kong  Science   46   56

# %%
                                     ### posibilities of not a number !!!

# %%
lis_dic_2 =[{
    'a' : 1,
    'b' : 2,
},
{
    'a' : 3,
    'b' : 4,
    'c' : 5
}
]

di_2 = pd.DataFrame(lis_dic_2)
print(di_2)
# Out:
#    a  b    c
# 0  1  2  NaN
# 1  3  4  5.0

# %%
di_2
# Out:
#    a  b    c
# 0  1  2  NaN
# 1  3  4  5.0

# %%
## read csv files 

import pandas as pd

# %%
help (pd.read_csv)
# Out:
# Help on function read_csv in module pandas.io.parsers:
#
# ...

# %%
# Read csv files !!!

# %%
pd.read_csv('/home/heathen/zillow.csv')
# Out:
#     Unnamed: 0              Country_name              Points
# 0            0           Manchester City                  18
# 1            1                 Liverpool                  14
# 2            2                   Chelsea                  13
# 3            3           West Ham United                  12
# 4            4         Manchester United                  11
# 5            5                   Arsenal                  11
# 6            6         Tottenham Hotspur                  11
# 7            7   Wolverhampton Wanderers                  10
# 8            8  Brighton and Hove Albion                   6
# 9            9            Leicester City                   7
# 10          10               Aston Villa                   8
# 11          11               Southampton                   5
# 12          12            Crystal Palace                   5
# 13          13                 Brentford                   6
# ...

# %%
# How to write csv files in pandas !!!

import pandas as pd1

# %%
pd1.read_csv('/home/heathen/zillow.csv')
# Out:
#     Unnamed: 0              Country_name              Points
# 0            0           Manchester City                  18
# 1            1                 Liverpool                  14
# 2            2                   Chelsea                  13
# 3            3           West Ham United                  12
# 4            4         Manchester United                  11
# 5            5                   Arsenal                  11
# 6            6         Tottenham Hotspur                  11
# 7            7   Wolverhampton Wanderers                  10
# 8            8  Brighton and Hove Albion                   6
# 9            9            Leicester City                   7
# 10          10               Aston Villa                   8
# 11          11               Southampton                   5
# 12          12            Crystal Palace                   5
# 13          13                 Brentford                   6
# ...

# %%
type(pd1)     ## type of its
# Out:
# module

# %%
pd1.read_csv('/home/heathen/zillow.csv', nrows = 3)      ## for rows<
# Out:
#    Unnamed: 0     Country_name              Points
# 0           0  Manchester City                  18
# 1           1        Liverpool                  14
# 2           2          Chelsea                  13

# %%
pd1.read_csv('/home/heathen/zillow.csv', usecols=[1, 1])           ## for coloums
# Out:
#                 Country_name
# 0            Manchester City
# 1                  Liverpool
# 2                    Chelsea
# 3            West Ham United
# 4          Manchester United
# 5                    Arsenal
# 6          Tottenham Hotspur
# 7    Wolverhampton Wanderers
# 8   Brighton and Hove Albion
# 9             Leicester City
# 10               Aston Villa
# 11               Southampton
# 12            Crystal Palace
# 13                 Brentford
# 14              Leeds United
# 15                   Everton
# 16          Newcastle United
# 17              Norwich City
# 18                   Watford
# 19                   Burnley

# %%
pd1.read_csv('/home/heathen/zillow.csv', skiprows =  [1,3,5,7,8])      ## for skiping rows
# Out:
#     Unnamed: 0              Country_name              Points
# 0            1                 Liverpool                  14
# 1            3           West Ham United                  12
# 2            5                   Arsenal                  11
# 3            8  Brighton and Hove Albion                   6
# 4            9            Leicester City                   7
# 5           10               Aston Villa                   8
# 6           11               Southampton                   5
# 7           12            Crystal Palace                   5
# 8           13                 Brentford                   6
# 9           14              Leeds United                   5
# 10          15                   Everton                   5
# 11          16          Newcastle United                   3
# 12          17              Norwich City                   4
# 13          18                   Watford                   4
# ...

# %%
pd1.read_csv('/home/heathen/zillow.csv', index_col = 'Country_name', usecols = [1,2])                   ## indexing columns
# Out:
#                                       Points
# Country_name
# Manchester City                           18
# Liverpool                                 14
# Chelsea                                   13
# West Ham United                           12
# Manchester United                         11
# Arsenal                                   11
# Tottenham Hotspur                         11
# Wolverhampton Wanderers                   10
# Brighton and Hove Albion                   6
# Leicester City                             7
# Aston Villa                                8
# Southampton                                5
# Crystal Palace                             5
# Brentford                                  6
# Leeds United                               5
# Everton                                    5
# Newcastle United                           3
# Norwich City                               4
# Watford                                    4
# ...

# %%
# Headers selection

# %%
pd1.read_csv('/home/heathen/zillow.csv')
# Out:
#     Unnamed: 0              Country_name              Points
# 0            0           Manchester City                  18
# 1            1                 Liverpool                  14
# 2            2                   Chelsea                  13
# 3            3           West Ham United                  12
# 4            4         Manchester United                  11
# 5            5                   Arsenal                  11
# 6            6         Tottenham Hotspur                  11
# 7            7   Wolverhampton Wanderers                  10
# 8            8  Brighton and Hove Albion                   6
# 9            9            Leicester City                   7
# 10          10               Aston Villa                   8
# 11          11               Southampton                   5
# 12          12            Crystal Palace                   5
# 13          13                 Brentford                   6
# ...

# %%
pd1.read_csv('/home/heathen/zillow.csv', header =3)           ## for header
# Out:
#      2                   Chelsea  13
# 0    3           West Ham United  12
# 1    4         Manchester United  11
# 2    5                   Arsenal  11
# 3    6         Tottenham Hotspur  11
# 4    7   Wolverhampton Wanderers  10
# 5    8  Brighton and Hove Albion   6
# 6    9            Leicester City   7
# 7   10               Aston Villa   8
# 8   11               Southampton   5
# 9   12            Crystal Palace   5
# 10  13                 Brentford   6
# 11  14              Leeds United   5
# 12  15                   Everton   5
# 13  16          Newcastle United   3
# 14  17              Norwich City   4
# 15  18                   Watford   4
# 16  19                   Burnley   1

# %%
pd1.read_csv('/home/heathen/zillow.csv', header = None )         # for not including header
# Out:
#        0                         1                   2
# 0    NaN              Country_name              Points
# 1    0.0           Manchester City                  18
# 2    1.0                 Liverpool                  14
# 3    2.0                   Chelsea                  13
# 4    3.0           West Ham United                  12
# 5    4.0         Manchester United                  11
# 6    5.0                   Arsenal                  11
# 7    6.0         Tottenham Hotspur                  11
# 8    7.0   Wolverhampton Wanderers                  10
# 9    8.0  Brighton and Hove Albion                   6
# 10   9.0            Leicester City                   7
# 11  10.0               Aston Villa                   8
# 12  11.0               Southampton                   5
# 13  12.0            Crystal Palace                   5
# 14  13.0                 Brentford                   6
# 15  14.0              Leeds United                   5
# ...

# %%
pd1.read_csv('/home/heathen/zillow.csv', header =None, prefix = 'A')         ## for using prefixing
# Out:
#       A0                        A1                  A2
# 0    NaN              Country_name              Points
# 1    0.0           Manchester City                  18
# 2    1.0                 Liverpool                  14
# 3    2.0                   Chelsea                  13
# 4    3.0           West Ham United                  12
# 5    4.0         Manchester United                  11
# 6    5.0                   Arsenal                  11
# 7    6.0         Tottenham Hotspur                  11
# 8    7.0   Wolverhampton Wanderers                  10
# 9    8.0  Brighton and Hove Albion                   6
# 10   9.0            Leicester City                   7
# 11  10.0               Aston Villa                   8
# 12  11.0               Southampton                   5
# 13  12.0            Crystal Palace                   5
# 14  13.0                 Brentford                   6
# 15  14.0              Leeds United                   5
# ...

# %%
pd1.read_csv('/home/heathen/zillow.csv', names = ['A','B','C', 'D'])    ## for using name
# Out:
#        A                         B                   C   D
# 0    NaN              Country_name              Points NaN
# 1    0.0           Manchester City                  18 NaN
# 2    1.0                 Liverpool                  14 NaN
# 3    2.0                   Chelsea                  13 NaN
# 4    3.0           West Ham United                  12 NaN
# 5    4.0         Manchester United                  11 NaN
# 6    5.0                   Arsenal                  11 NaN
# 7    6.0         Tottenham Hotspur                  11 NaN
# 8    7.0   Wolverhampton Wanderers                  10 NaN
# 9    8.0  Brighton and Hove Albion                   6 NaN
# 10   9.0            Leicester City                   7 NaN
# 11  10.0               Aston Villa                   8 NaN
# 12  11.0               Southampton                   5 NaN
# 13  12.0            Crystal Palace                   5 NaN
# 14  13.0                 Brentford                   6 NaN
# ...

# %%
#   Head and tail

# %%
import pandas as pd

# %%
d_ff = pd1.read_csv('/home/heathen/zillow.csv')

# %%
d_ff.head()               ## for print 1st five rows
# Out:
#    Unnamed: 0       Country_name              Points
# 0           0    Manchester City                  18
# 1           1          Liverpool                  14
# 2           2            Chelsea                  13
# 3           3    West Ham United                  12
# 4           4  Manchester United                  11

# %%
d_ff.head(3)                         ## print according to your choices
# Out:
#    Unnamed: 0     Country_name              Points
# 0           0  Manchester City                  18
# 1           1        Liverpool                  14
# 2           2          Chelsea                  13

# %%
d_ff.tail()                ## for printing last five rows
# Out:
#     Unnamed: 0      Country_name              Points
# 15          15           Everton                   5
# 16          16  Newcastle United                   3
# 17          17      Norwich City                   4
# 18          18           Watford                   4
# 19          19           Burnley                   1

# %%
d_ff.tail(3)            ## your choice to print rows !!!
# Out:
#     Unnamed: 0  Country_name              Points
# 17          17  Norwich City                   4
# 18          18       Watford                   4
# 19          19       Burnley                   1

# %%
## to changing Data<->types of values        &&  True and False values !!!!

# %%
dl =pd1.read_csv('/home/heathen/zillow.csv', dtype = {'':  'float64'})
dl
# Out:
#     Unnamed: 0              Country_name              Points
# 0            0           Manchester City                  18
# 1            1                 Liverpool                  14
# 2            2                   Chelsea                  13
# 3            3           West Ham United                  12
# 4            4         Manchester United                  11
# 5            5                   Arsenal                  11
# 6            6         Tottenham Hotspur                  11
# 7            7   Wolverhampton Wanderers                  10
# 8            8  Brighton and Hove Albion                   6
# 9            9            Leicester City                   7
# 10          10               Aston Villa                   8
# 11          11               Southampton                   5
# 12          12            Crystal Palace                   5
# 13          13                 Brentford                   6
# ...

# %%
pd1.read_csv('/home/heathen/zillow.csv', true_values =['Liverpool'])
# Out:
#     Unnamed: 0              Country_name              Points
# 0            0           Manchester City                  18
# 1            1                 Liverpool                  14
# 2            2                   Chelsea                  13
# 3            3           West Ham United                  12
# 4            4         Manchester United                  11
# 5            5                   Arsenal                  11
# 6            6         Tottenham Hotspur                  11
# 7            7   Wolverhampton Wanderers                  10
# 8            8  Brighton and Hove Albion                   6
# 9            9            Leicester City                   7
# 10          10               Aston Villa                   8
# 11          11               Southampton                   5
# 12          12            Crystal Palace                   5
# 13          13                 Brentford                   6
# ...

# %%
## Handling mixing values Python!!!

# %%
pd1.read_csv('/home/heathen/zilloww.csv')                ### NAN means not a numbes !!!
# Out:
#     Unnamed: 0              Country_name              Points
# 0            0           Manchester City                18.0
# 1            1                 Liverpool                14.0
# 2            2                   Chelsea                 NaN
# 3            3           West Ham United                 NaN
# 4            4         Manchester United                11.0
# 5            5                   Arsenal                11.0
# 6            6         Tottenham Hotspur                11.0
# 7            7   Wolverhampton Wanderers                10.0
# 8            8  Brighton and Hove Albion                 NaN
# 9            9            Leicester City                 7.0
# 10          10               Aston Villa                 8.0
# 11          11               Southampton                 5.0
# 12          12            Crystal Palace                 NaN
# 13          13                 Brentford                 6.0
# ...

# %%
pd1.read_csv('/home/heathen/zillow.csv', na_values = ['Burnley', 'Liverpool'])        ##  select for NAN VALUES
# Out:
#     Unnamed: 0              Country_name              Points
# 0            0           Manchester City                  18
# 1            1                       NaN                  14
# 2            2                   Chelsea                  13
# 3            3           West Ham United                  12
# 4            4         Manchester United                  11
# 5            5                   Arsenal                  11
# 6            6         Tottenham Hotspur                  11
# 7            7   Wolverhampton Wanderers                  10
# 8            8  Brighton and Hove Albion                   6
# 9            9            Leicester City                   7
# 10          10               Aston Villa                   8
# 11          11               Southampton                   5
# 12          12            Crystal Palace                   5
# 13          13                 Brentford                   6
# ...

# %%
pd1.read_csv('/home/heathen/zilloww.csv', keep_default_na = False)       ## donot want NAN VALUES !!!
# Out:
#     Unnamed: 0              Country_name             Points
# 0            0           Manchester City                 18
# 1            1                 Liverpool                 14
# 2            2                   Chelsea
# 3            3           West Ham United
# 4            4         Manchester United                 11
# 5            5                   Arsenal                 11
# 6            6         Tottenham Hotspur                 11
# 7            7   Wolverhampton Wanderers                 10
# 8            8  Brighton and Hove Albion
# 9            9            Leicester City                  7
# 10          10               Aston Villa                  8
# 11          11               Southampton                  5
# 12          12            Crystal Palace
# 13          13                 Brentford                  6
# 14          14              Leeds United                  5
# 15          15                   Everton
# ...

# %%
pd1.read_csv('/home/heathen/zilloww.csv', na_filter = True)       ##  filter of nan
# Out:
#     Unnamed: 0              Country_name              Points
# 0            0           Manchester City                18.0
# 1            1                 Liverpool                14.0
# 2            2                   Chelsea                 NaN
# 3            3           West Ham United                 NaN
# 4            4         Manchester United                11.0
# 5            5                   Arsenal                11.0
# 6            6         Tottenham Hotspur                11.0
# 7            7   Wolverhampton Wanderers                10.0
# 8            8  Brighton and Hove Albion                 NaN
# 9            9            Leicester City                 7.0
# 10          10               Aston Villa                 8.0
# 11          11               Southampton                 5.0
# 12          12            Crystal Palace                 NaN
# 13          13                 Brentford                 6.0
# ...

# %%
pd1.read_csv('/home/heathen/zilloww.csv', na_filter = False)       ##  filter of nan
# Out:
#     Unnamed: 0              Country_name             Points
# 0            0           Manchester City                 18
# 1            1                 Liverpool                 14
# 2            2                   Chelsea
# 3            3           West Ham United
# 4            4         Manchester United                 11
# 5            5                   Arsenal                 11
# 6            6         Tottenham Hotspur                 11
# 7            7   Wolverhampton Wanderers                 10
# 8            8  Brighton and Hove Albion
# 9            9            Leicester City                  7
# 10          10               Aston Villa                  8
# 11          11               Southampton                  5
# 12          12            Crystal Palace
# 13          13                 Brentford                  6
# 14          14              Leeds United                  5
# 15          15                   Everton
# ...

# %%
## How many NAN VALUES in files

# %%
df3 = pd1.read_csv('/home/heathen/zilloww.csv')

# %%
df3.isnull().sum()
# Out:
# Unnamed: 0            0
# Country_name          0
#             Points    6
# dtype: int64

# %%
df3.isnull().sum().sum()
# Out:
# 6

# %%
## how many not null in files !!!

# %%
df3 = pd1.read_csv('/home/heathen/zilloww.csv')

# %%
df3.notnull().sum()
# Out:
# Unnamed: 0            20
# Country_name          20
#             Points    14
# dtype: int64

# %%
df3.notnull().sum().sum()
# Out:
# 54

# %%
## if any row have NAN VALUES  to drop out of this !!!

# %%
df4= pd1.read_csv('/home/heathen/zilloww.csv')

# %%
df4.dropna(how = 'any')
# Out:
#     Unnamed: 0             Country_name              Points
# 0            0          Manchester City                18.0
# 1            1                Liverpool                14.0
# 4            4        Manchester United                11.0
# 5            5                  Arsenal                11.0
# 6            6        Tottenham Hotspur                11.0
# 7            7  Wolverhampton Wanderers                10.0
# 9            9           Leicester City                 7.0
# 10          10              Aston Villa                 8.0
# 11          11              Southampton                 5.0
# 13          13                Brentford                 6.0
# 14          14             Leeds United                 5.0
# 16          16         Newcastle United                 3.0
# 17          17             Norwich City                 4.0
# 19          19                  Burnley                 1.0

# %%
## pandas FILL NA METHODS  to fillout nan valeus

# %%
df_5 = pd1.read_csv('/home/heathen/zilloww.csv')

# %%
df_5.fillna('khaliii haii')
# Out:
#     Unnamed: 0              Country_name             Points
# 0            0           Manchester City               18.0
# 1            1                 Liverpool               14.0
# 2            2                   Chelsea       khaliii haii
# 3            3           West Ham United       khaliii haii
# 4            4         Manchester United               11.0
# 5            5                   Arsenal               11.0
# 6            6         Tottenham Hotspur               11.0
# 7            7   Wolverhampton Wanderers               10.0
# 8            8  Brighton and Hove Albion       khaliii haii
# 9            9            Leicester City                7.0
# 10          10               Aston Villa                8.0
# 11          11               Southampton                5.0
# 12          12            Crystal Palace       khaliii haii
# 13          13                 Brentford                6.0
# 14          14              Leeds United                5.0
# ...

# %%
## Add previous valuee on the NAN VALUES  {method = forward fill or backward fill}

# %%
df_6 = pd1.read_csv('/home/heathen/zilloww.csv')

# %%
df_6.fillna(method = 'ffill')
# Out:
#     Unnamed: 0              Country_name              Points
# 0            0           Manchester City                18.0
# 1            1                 Liverpool                14.0
# 2            2                   Chelsea                14.0
# 3            3           West Ham United                14.0
# 4            4         Manchester United                11.0
# 5            5                   Arsenal                11.0
# 6            6         Tottenham Hotspur                11.0
# 7            7   Wolverhampton Wanderers                10.0
# 8            8  Brighton and Hove Albion                10.0
# 9            9            Leicester City                 7.0
# 10          10               Aston Villa                 8.0
# 11          11               Southampton                 5.0
# 12          12            Crystal Palace                 5.0
# 13          13                 Brentford                 6.0
# ...

# %%
df_6.fillna(method = 'bfill')                   ### backward fill
# Out:
#     Unnamed: 0              Country_name              Points
# 0            0           Manchester City                18.0
# 1            1                 Liverpool                14.0
# 2            2                   Chelsea                11.0
# 3            3           West Ham United                11.0
# 4            4         Manchester United                11.0
# 5            5                   Arsenal                11.0
# 6            6         Tottenham Hotspur                11.0
# 7            7   Wolverhampton Wanderers                10.0
# 8            8  Brighton and Hove Albion                 7.0
# 9            9            Leicester City                 7.0
# 10          10               Aston Villa                 8.0
# 11          11               Southampton                 5.0
# 12          12            Crystal Palace                 6.0
# 13          13                 Brentford                 6.0
# ...

# %%
## Somethings replacement with others !!!!

# %%
df_7 = pd1.read_csv('/home/heathen/zilloww.csv')

# %%
df_7.replace(to_replace = 'Manchester City', value = 'Haider')
# Out:
#     Unnamed: 0              Country_name              Points
# 0            0                    Haider                18.0
# 1            1                 Liverpool                14.0
# 2            2                   Chelsea                 NaN
# 3            3           West Ham United                 NaN
# 4            4         Manchester United                11.0
# 5            5                   Arsenal                11.0
# 6            6         Tottenham Hotspur                11.0
# 7            7   Wolverhampton Wanderers                10.0
# 8            8  Brighton and Hove Albion                 NaN
# 9            9            Leicester City                 7.0
# 10          10               Aston Villa                 8.0
# 11          11               Southampton                 5.0
# 12          12            Crystal Palace                 NaN
# 13          13                 Brentford                 6.0
# ...

# %%
df_7.replace([0,1,2,3], [0,'A','B',33])                     # replacement !!!
# Out:
#    Unnamed: 0              Country_name             Points
# 0           0           Manchester City               18.0
# 1           A                 Liverpool               14.0
# 2           B                   Chelsea                NaN
# 3          33           West Ham United                NaN
# 4           4         Manchester United               11.0
# 5           5                   Arsenal               11.0
# 6           6         Tottenham Hotspur               11.0
# 7           7   Wolverhampton Wanderers               10.0
# 8           8  Brighton and Hove Albion                NaN
# 9           9            Leicester City                7.0
# 10         10               Aston Villa                8.0
# 11         11               Southampton                5.0
# 12         12            Crystal Palace                NaN
# 13         13                 Brentford                6.0
# 14         14              Leeds United                5.0
# ...

# %%
### pandas interpolates   means give somevalues to NAN VALUES

# %%
df_8 = pd1.read_csv('/home/heathen/zilloww.csv')

# %%
df_8.interpolate()
# Out:
#     Unnamed: 0              Country_name              Points
# 0            0           Manchester City                18.0
# 1            1                 Liverpool                14.0
# 2            2                   Chelsea                13.0
# 3            3           West Ham United                12.0
# 4            4         Manchester United                11.0
# 5            5                   Arsenal                11.0
# 6            6         Tottenham Hotspur                11.0
# 7            7   Wolverhampton Wanderers                10.0
# 8            8  Brighton and Hove Albion                 8.5
# 9            9            Leicester City                 7.0
# 10          10               Aston Villa                 8.0
# 11          11               Southampton                 5.0
# 12          12            Crystal Palace                 5.5
# 13          13                 Brentford                 6.0
# ...

# %%
df_8.dtypes
# Out:
# Unnamed: 0              int64
# Country_name           object
#             Points    float64
# dtype: object

# %%
## loc python pandas    same as iloc

# %%
df_9 = pd1.read_csv('/home/heathen/zilloww.csv')

# %%
df_9.loc[1]
# Out:
# Unnamed: 0                    1
# Country_name          Liverpool
#             Points         14.0
# Name: 1, dtype: object

# %%
df_9.loc[2]
# Out:
# Unnamed: 0                  2
# Country_name          Chelsea
#             Points        NaN
# Name: 2, dtype: object

# %%
df_9.loc[5]
# Out:
# Unnamed: 0                  5
# Country_name          Arsenal
#             Points       11.0
# Name: 5, dtype: object

# %%
df_9.loc[[1,2,5]]                      ## both
# Out:
#    Unnamed: 0 Country_name              Points
# 1           1    Liverpool                14.0
# 2           2      Chelsea                 NaN
# 5           5      Arsenal                11.0

# %%
## pandas merging dataframees

# %%
df_10 =pd.DataFrame({
    "Name " : ['Haider', 'king', 'Haideee', 'Ali'],
     "ID" : [1,2,3,4]
 })
df_10
# Out:
#      Name   ID
# 0   Haider   1
# 1     king   2
# 2  Haideee   3
# 3      Ali   4

# %%
df_11 =pd.DataFrame({
    "Games" : ['GTA', 'THE LION KING', 'DRAGON BALL Z', 'TAKKEN'],
    "ID" : [1,2,3,4]
 })
df_11
# Out:
#            Games  ID
# 0            GTA   1
# 1  THE LION KING   2
# 2  DRAGON BALL Z   3
# 3         TAKKEN   4

# %%
pd.merge(df_10,df_11,  on = 'ID')
# Out:
#      Name   ID          Games
# 0   Haider   1            GTA
# 1     king   2  THE LION KING
# 2  Haideee   3  DRAGON BALL Z
# 3      Ali   4         TAKKEN

# %%
## Concate pandas in python

# %%
df_12 =pd.DataFrame({
    "ID" : [1,2,3,4],
    "Name " : ['Haider', 'king', 'Haideee', 'Ali']
     
 })
df_12
# Out:
#    ID    Name
# 0   1   Haider
# 1   2     king
# 2   3  Haideee
# 3   4      Ali

# %%
df_13 =pd.DataFrame({
    "ID" : [5,6,7,8],
    "Name" : ['GTA', 'THE LION KING', 'DRAGON BALL Z', 'TAKKEN']
   
 })
df_13
# Out:
#    ID           Name
# 0   5            GTA
# 1   6  THE LION KING
# 2   7  DRAGON BALL Z
# 3   8         TAKKEN

# %%
pd.concat([df_12, df_13], ignore_index=True)
# Out:
#    ID    Name            Name
# 0   1   Haider            NaN
# 1   2     king            NaN
# 2   3  Haideee            NaN
# 3   4      Ali            NaN
# 4   5      NaN            GTA
# 5   6      NaN  THE LION KING
# 6   7      NaN  DRAGON BALL Z
# 7   8      NaN         TAKKEN

# %%
##///////////////////////////////////////////////////////////////////////////////////////////////////
#///////////////////////////////////////////////////////////////////////////////////////////////////
